# %%
# !pip install transformers

# %%
pip install torch
# Out:
# ...
#   Using cached torch-2.2.2-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/198.6 MB 388.9 kB/s eta 0:08:31
#    ---------------------------------------- 0.1/198.6 MB 465.5 kB/s eta 0:07:07
#    ---------------------------------------- 0.1/198.6 MB 652.2 kB/s eta 0:05:05
#    ---------------------------------------- 0.2/198.6 MB 654.6 kB/s eta 0:05:04
#    ---------------------------------------- 0.3/198.6 MB 1.1 MB/s eta 0:03:09
#    ---------------------------------------- 0.5/198.6 MB 1.6 MB/s eta 0:02:03
#    ---------------------------------------- 0.6/198.6 MB 1.6 MB/s eta 0:02:01
#    ---------------------------------------- 0.7/198.6 MB 1.7 MB/s eta 0:02:00
#    ---------------------------------------- 0.8/198.6 MB 1.9 MB/s eta 0:01:44
# ...

# %%
from transformers import pipeline

# %%
pipe = pipeline('text-classification')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
pipe("i like to think in negative way")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9990412592887878}]

# %%
pip install streamlit
# Out:
# ...
#
# ...
